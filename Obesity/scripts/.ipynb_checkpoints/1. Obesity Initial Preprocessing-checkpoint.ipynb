# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd

# %%
import os

# %% [markdown]
# #### Reading Files

# %%
df_state = pd.read_excel("C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/state_tax.xlsx")

# %%
df_state
# Out:
#         State        Tax_Type  Year  Rate Notes_On_Tax_Rate  Rate 2
# 0     Alabama  Restaurant Tax  1970   NaN               NaN     NaN
# 1     Alabama  Restaurant Tax  1971   NaN               NaN     NaN
# 2     Alabama  Restaurant Tax  1972   NaN               NaN     NaN
# 3     Alabama  Restaurant Tax  1973   NaN               NaN     NaN
# 4     Alabama  Restaurant Tax  1974   NaN               NaN     NaN
# ...       ...             ...   ...   ...               ...     ...
# 5295  Wyoming     Grocery Tax  2018   0.0               NaN     0.0
# 5296  Wyoming     Grocery Tax  2019   0.0               NaN     0.0
# 5297  Wyoming     Grocery Tax  2020   0.0               NaN     0.0
# 5298  Wyoming     Grocery Tax  2021   0.0               NaN     0.0
# 5299  Wyoming     Grocery Tax  2022   0.0               NaN     0.0
#
# [5300 rows x 6 columns]

# %%
# Function to read and merge csv files in a folder to a dataframe
def merge_csv_files_in_folder(folder_path):
    # Create an empty list to store DataFrames
    dfs = []

    # Define the expected prefix of the filenames
    filename_prefix = "ObesityAtlas_CountyData_"

    # Iterate through the files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv") and filename.startswith(filename_prefix):
            # Attempt to extract the year from the filename
            try:
                year = int(filename[len(filename_prefix):-4])
            except ValueError:
                # If the year extraction fails, skip the file
                print(f"Skipping file {filename} due to invalid year format.")
                continue
            
            file_path = os.path.join(folder_path, filename)
            
            # Determine the number of lines in the file
            with open(file_path) as f:
                num_lines = sum(1 for _ in f)
            
            # Read the CSV file, skipping the first two rows and the last row
            df = pd.read_csv(file_path, skiprows=2, skipfooter=1, engine='python')
            
            # Add a "Year" column with the extracted year
            df["Year"] = year
            
            # Append the DataFrame to the list
            dfs.append(df)

    # Concatenate all DataFrames into a single DataFrame
    if dfs:
        final_df = pd.concat(dfs, ignore_index=True)
        # print("Concatenation successful.")
        return final_df
    else:
        print("No CSV files matching the expected format found in the folder.")
        return None

# %% [markdown]
# Obesity Total

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Total' 
obese_county_absolute_total = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_total.rename(columns={'Number':'Total Absolute','Lower Limit':'Total Absolute LL',' Upper Limit':'Total Absolute UL'},inplace=True)

# %%
obese_county_absolute_total
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Total Absolute Total Absolute LL Total Absolute UL  Year
# 0            No Data           No Data           No Data  2004
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Total' 
obese_county_percentage_total = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_total.rename(columns={'Percentage':'Total Percentage','Lower Limit':'Total Percentage LL',' Upper Limit':'Total Percentage UL'},inplace=True)

# %%
obese_county_percentage_total
# Out:
#                                   County          State  CountyFIPS  \
# 0                   Oglala Lakota County   South Dakota       46102
# 1              Wrangell City and Borough         Alaska        2275
# 2                   Skagway Municipality         Alaska        2230
# 3      Prince of Wales-Hyder Census Area         Alaska        2198
# 4                     Petersburg Borough         Alaska        2195
# ...                                  ...            ...         ...
# 53513                     Lincoln County       Oklahoma       40081
# 53514                       Boone County  West Virginia       54005
# 53515                    Maverick County          Texas       48323
# 53516                     Leflore County    Mississippi       28083
# 53517                     Rolette County   North Dakota       38079
#
#       Total Percentage Total Percentage LL Total Percentage UL  Year
# 0              No Data             No Data             No Data  2004
# ...

# %%
df_obese_total = pd.merge(obese_county_absolute_total, obese_county_percentage_total, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_total
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Total Absolute Total Absolute LL Total Absolute UL  Year  \
# 0            No Data           No Data           No Data  2004
# ...

# %% [markdown]
# Obesity Gender

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Gender/Male' 
obese_county_absolute_male = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_male.rename(columns={'Number':'Male Absolute','Lower Limit':'Male Absolute LL',' Upper Limit':'Male Absolute UL'},inplace=True)
obese_county_absolute_male
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                        Cook County      Illinois       17031
# 53515                    Maricopa County       Arizona        4013
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Male Absolute Male Absolute LL Male Absolute UL  Year
# 0           No Data          No Data          No Data  2004
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Gender/Male' 
obese_county_percentage_male = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_male.rename(columns={'Percentage':'Male Percentage','Lower Limit':'Male Percentage LL',' Upper Limit':'Male Percentage UL'},inplace=True)
obese_county_percentage_male
# Out:
#                                   County          State  CountyFIPS  \
# 0                   Oglala Lakota County   South Dakota       46102
# 1              Wrangell City and Borough         Alaska        2275
# 2                   Skagway Municipality         Alaska        2230
# 3      Prince of Wales-Hyder Census Area         Alaska        2198
# 4                     Petersburg Borough         Alaska        2195
# ...                                  ...            ...         ...
# 53513                       Logan County  West Virginia       54045
# 53514                     Lincoln County       Oklahoma       40081
# 53515                     Rolette County   North Dakota       38079
# 53516                    Maverick County          Texas       48323
# 53517                       Boone County  West Virginia       54005
#
#       Male Percentage Male Percentage LL Male Percentage UL  Year
# 0             No Data            No Data            No Data  2004
# ...

# %%
df_obese_male = pd.merge(obese_county_absolute_male, obese_county_percentage_male, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_male
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                        Cook County      Illinois       17031
# 53515                    Maricopa County       Arizona        4013
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Male Absolute Male Absolute LL Male Absolute UL  Year Male Percentage  \
# 0           No Data          No Data          No Data  2004         No Data
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Gender/Female' 
obese_county_absolute_female = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_female.rename(columns={'Number':'Female Absolute','Lower Limit':'Female Absolute LL',' Upper Limit':'Female Absolute UL'},inplace=True)
obese_county_absolute_female
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                      Dallas County         Texas       48113
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Female Absolute Female Absolute LL Female Absolute UL  Year
# 0             No Data            No Data            No Data  2004
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Gender/Female' 
obese_county_percentage_female = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_female.rename(columns={'Percentage':'Female Percentage','Lower Limit':'Female Percentage LL',' Upper Limit':'Female Percentage UL'},inplace=True)
obese_county_percentage_female
# Out:
#                                   County           State  CountyFIPS  \
# 0                   Oglala Lakota County    South Dakota       46102
# 1              Wrangell City and Borough          Alaska        2275
# 2                   Skagway Municipality          Alaska        2230
# 3      Prince of Wales-Hyder Census Area          Alaska        2198
# 4                     Petersburg Borough          Alaska        2195
# ...                                  ...             ...         ...
# 53513                  Montgomery County         Alabama        1101
# 53514                     Robeson County  North Carolina       37155
# 53515                   Sunflower County     Mississippi       28133
# 53516                     Rolette County    North Dakota       38079
# 53517                     Leflore County     Mississippi       28083
#
#       Female Percentage Female Percentage LL Female Percentage UL  Year
# ...

# %%
df_obese_female = pd.merge(obese_county_absolute_female, obese_county_percentage_female, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_female
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                      Dallas County         Texas       48113
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Female Absolute Female Absolute LL Female Absolute UL  Year  \
# 0             No Data            No Data            No Data  2004
# ...

# %% [markdown]
# Obesity Age

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Age/20_44' 
obese_county_absolute_age_20_to_44 = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_age_20_to_44.rename(columns={'Number':'Age_20_to_44 Absolute','Lower Limit':'Age_20_to_44 Absolute LL',' Upper Limit':'Age_20_to_44 Absolute UL'},inplace=True)
obese_county_absolute_age_20_to_44
# Out:
#                    County       State  CountyFIPS Age_20_to_44 Absolute  \
# 0           Loving County       Texas       48301            Suppressed
# 1          Kalawao County      Hawaii       15005            Suppressed
# 2           Arthur County    Nebraska       31005                    17
# 3             King County       Texas       48269                    18
# 4           Blaine County    Nebraska       31009                    21
# ...                   ...         ...         ...                   ...
# 53395       Dallas County       Texas       48113                281916
# 53396     Maricopa County     Arizona        4013                410282
# 53397         Cook County    Illinois       17031                445411
# 53398       Harris County       Texas       48201                508507
# 53399  Los Angeles County  California        6037                817871
#
#       Age_20_to_44 Absolute LL Age_20_to_44 Absolute UL  Year
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Age/20_44' 
obese_county_percentage_age_20_to_44 = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_age_20_to_44.rename(columns={'Percentage':'Age_20_to_44 Percentage','Lower Limit':'Age_20_to_44 Percentage LL',' Upper Limit':'Age_20_to_44 Percentage UL'},inplace=True)
obese_county_percentage_age_20_to_44
# Out:
#                 County           State  CountyFIPS Age_20_to_44 Percentage  \
# 0         Teton County         Wyoming       56039                    11.2
# 1        Summit County            Utah       49043                    11.5
# 2       Boulder County        Colorado        8013                    12.2
# 3       Douglas County        Colorado        8035                    12.3
# 4        Blaine County           Idaho       16013                    12.3
# ...                ...             ...         ...                     ...
# 53395     Boone County   West Virginia       54005                    42.7
# 53396   Robeson County  North Carolina       37155                    43.6
# 53397  Maverick County           Texas       48323                    43.8
# 53398   Leflore County     Mississippi       28083                    47.5
# 53399   Rolette County    North Dakota       38079                    47.7
#
#       Age_20_to_44 Percentage LL Age_20_to_44 Percentage UL  Year
# ...

# %%
df_obese_age_20_to_44 = pd.merge(obese_county_absolute_age_20_to_44, obese_county_percentage_age_20_to_44, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_age_20_to_44
# Out:
#                    County       State  CountyFIPS Age_20_to_44 Absolute  \
# 0           Loving County       Texas       48301            Suppressed
# 1          Kalawao County      Hawaii       15005            Suppressed
# 2           Arthur County    Nebraska       31005                    17
# 3             King County       Texas       48269                    18
# 4           Blaine County    Nebraska       31009                    21
# ...                   ...         ...         ...                   ...
# 53395       Dallas County       Texas       48113                281916
# 53396     Maricopa County     Arizona        4013                410282
# 53397         Cook County    Illinois       17031                445411
# 53398       Harris County       Texas       48201                508507
# 53399  Los Angeles County  California        6037                817871
#
#       Age_20_to_44 Absolute LL Age_20_to_44 Absolute UL  Year  \
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Age/45_64' 
obese_county_absolute_age_45_to_64 = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_age_45_to_64.rename(columns={'Number':'Age_45_to_64 Absolute','Lower Limit':'Age_45_to_64 Absolute LL',' Upper Limit':'Age_45_to_64 Absolute UL'},inplace=True)
obese_county_absolute_age_45_to_64
# Out:
#                    County       State  CountyFIPS Age_45_to_64 Absolute  \
# 0           Loving County       Texas       48301            Suppressed
# 1          Kalawao County      Hawaii       15005                    14
# 2             King County       Texas       48269                    18
# 3           Arthur County    Nebraska       31005                    23
# 4           Kenedy County       Texas       48261                    24
# ...                   ...         ...         ...                   ...
# 53395    San Diego County  California        6073                236123
# 53396     Maricopa County     Arizona        4013                372088
# 53397         Cook County    Illinois       17031                391096
# 53398       Harris County       Texas       48201                441893
# 53399  Los Angeles County  California        6037                787052
#
#       Age_45_to_64 Absolute LL Age_45_to_64 Absolute UL  Year
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Age/45_64' 
obese_county_percentage_age_45_to_64 = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_age_45_to_64.rename(columns={'Percentage':'Age_45_to_64 Percentage','Lower Limit':'Age_45_to_64 Percentage LL',' Upper Limit':'Age_20_to_44 Percentage UL'},inplace=True)
obese_county_percentage_age_45_to_64
# Out:
#                 County          State  CountyFIPS Age_45_to_64 Percentage  \
# 0        Summit County           Utah       49043                    13.2
# 1         Teton County        Wyoming       56039                    13.9
# 2      Santa Fe County     New Mexico       35049                    15.2
# 3        Blaine County          Idaho       16013                    15.7
# 4       Boulder County       Colorado        8013                    15.9
# ...                ...            ...         ...                     ...
# 53395     Boone County  West Virginia       54005                    49.4
# 53396     Logan County  West Virginia       54045                    50.4
# 53397  Maverick County          Texas       48323                    50.9
# 53398   Rolette County   North Dakota       38079                      53
# 53399   Leflore County    Mississippi       28083                    54.2
#
#       Age_45_to_64 Percentage LL Age_20_to_44 Percentage UL  Year
# ...

# %%
df_obese_age_45_to_64 = pd.merge(obese_county_absolute_age_45_to_64, obese_county_percentage_age_45_to_64, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_age_45_to_64
# Out:
#                    County       State  CountyFIPS Age_45_to_64 Absolute  \
# 0           Loving County       Texas       48301            Suppressed
# 1          Kalawao County      Hawaii       15005                    14
# 2             King County       Texas       48269                    18
# 3           Arthur County    Nebraska       31005                    23
# 4           Kenedy County       Texas       48261                    24
# ...                   ...         ...         ...                   ...
# 53395    San Diego County  California        6073                236123
# 53396     Maricopa County     Arizona        4013                372088
# 53397         Cook County    Illinois       17031                391096
# 53398       Harris County       Texas       48201                441893
# 53399  Los Angeles County  California        6037                787052
#
#       Age_45_to_64 Absolute LL Age_45_to_64 Absolute UL  Year  \
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Absolute/Age/65_beyond' 
obese_county_absolute_age_65_to_beyond = merge_csv_files_in_folder(folder_path)

# %%
obese_county_absolute_age_65_to_beyond.rename(columns={'Number':'Age_65_to_beyond Absolute','Lower Limit':'Age_65_to_beyond Absolute LL',' Upper Limit':'Age_65_to_beyond Absolute UL'},inplace=True)
obese_county_absolute_age_65_to_beyond
# Out:
#                          County       State  CountyFIPS  \
# 0                 Loving County       Texas       48301
# 1                Kalawao County      Hawaii       15005
# 2                   King County       Texas       48269
# 3               San Juan County    Colorado        8111
# 4      Yakutat City and Borough      Alaska        2282
# ...                         ...         ...         ...
# 53395          San Diego County  California        6073
# 53396             Harris County       Texas       48201
# 53397           Maricopa County     Arizona        4013
# 53398               Cook County    Illinois       17031
# 53399        Los Angeles County  California        6037
#
#       Age_65_to_beyond Absolute Age_65_to_beyond Absolute LL  \
# 0                    Suppressed                   Suppressed
# 1                    Suppressed                   Suppressed
# 2                    Suppressed                   Suppressed
# ...

# %%
folder_path = 'C:/Users/nidsp/OneDrive - Illinois Institute of Technology/Desktop/Illinois Institute of Technology Courseworks/RES-MATCH/Obesity_Percentage/Age/65_beyond' 
obese_county_percentage_age_65_to_beyond = merge_csv_files_in_folder(folder_path)

# %%
obese_county_percentage_age_65_to_beyond.rename(columns={'Percentage':'Age_65_to_beyond Percentage','Lower Limit':'Age_65_to_beyond Percentage LL',' Upper Limit':'Age_65_to_beyond Percentage UL'},inplace=True)
obese_county_percentage_age_65_to_beyond
# Out:
#                 County          State  CountyFIPS Age_65_to_beyond Percentage  \
# 0        Summit County           Utah       49043                        10.1
# 1         Teton County        Wyoming       56039                        10.3
# 2       Boulder County       Colorado        8013                        10.9
# 3        Blaine County          Idaho       16013                        11.1
# 4      Santa Fe County     New Mexico       35049                        11.1
# ...                ...            ...         ...                         ...
# 53395   Lincoln County       Oklahoma       40081                        41.7
# 53396   Rolette County   North Dakota       38079                        41.9
# 53397   Leflore County    Mississippi       28083                          42
# 53398     Boone County  West Virginia       54005                          43
# 53399  Maverick County          Texas       48323                        43.1
#
# ...

# %%
df_obese_age_65_to_beyond = pd.merge(obese_county_absolute_age_65_to_beyond, obese_county_percentage_age_65_to_beyond, how='inner', on=['State', 'County', 'CountyFIPS', 'Year'])
df_obese_age_65_to_beyond
# Out:
#                          County       State  CountyFIPS  \
# 0                 Loving County       Texas       48301
# 1                Kalawao County      Hawaii       15005
# 2                   King County       Texas       48269
# 3               San Juan County    Colorado        8111
# 4      Yakutat City and Borough      Alaska        2282
# ...                         ...         ...         ...
# 53395          San Diego County  California        6073
# 53396             Harris County       Texas       48201
# 53397           Maricopa County     Arizona        4013
# 53398               Cook County    Illinois       17031
# 53399        Los Angeles County  California        6037
#
#       Age_65_to_beyond Absolute Age_65_to_beyond Absolute LL  \
# 0                    Suppressed                   Suppressed
# 1                    Suppressed                   Suppressed
# 2                    Suppressed                   Suppressed
# ...

# %% [markdown]
# #### Data Preprocessing

# %%
# Finalizing state dataframe by filtering on years from 2000
df_state = df_state[df_state['Year']>=2000]

# %%
# Checking for missing rate for states
missing_rate = df_state[df_state['Rate'].isnull()]
missing_rate
# Out:
# Empty DataFrame
# Columns: [State, Tax_Type, Year, Rate, Notes_On_Tax_Rate, Rate 2]
# Index: []

# %%
# Finalizing Obesity county total dataframe
df_obese_total
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Total Absolute Total Absolute LL Total Absolute UL  Year  \
# 0            No Data           No Data           No Data  2004
# ...

# %%
# Checking for No data in Obesity county total
missing_obese_county_total = df_obese_total[(df_obese_total['Total Absolute'] == 'No Data') | (df_obese_total['Total Percentage'] == 'No Data')]
missing_obese_county_total
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 50370    Wrangell-Petersburg Census Area        Alaska        2280
# 50371           Wade Hampton Census Area        Alaska        2270
# 50372         Valdez-Cordova Census Area        Alaska        2261
# 50373              Skagway-Hoonah-Angoon        Alaska        2232
# 50374  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Total Absolute Total Absolute LL Total Absolute UL  Year  \
# 0            No Data           No Data           No Data  2004
# ...

# %%
# Finalizing Obesity county male dataframe
df_obese_male['Gender'] = 'Male'
df_obese_male.rename(columns={'Male Absolute':'Gender Absolute','Male Percentage':'Gender Percentage'},inplace=True)
df_obese_male
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                   San Diego County    California        6073
# 53514                        Cook County      Illinois       17031
# 53515                    Maricopa County       Arizona        4013
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Gender Absolute Male Absolute LL Male Absolute UL  Year  \
# 0             No Data          No Data          No Data  2004
# ...

# %%
# Checking for No data in Obesity county male
missing_obese_county_male = df_obese_male[(df_obese_male['Gender Absolute']=='No Data')|(df_obese_male['Gender Percentage']=='No Data')]
missing_obese_county_male
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 50370    Wrangell-Petersburg Census Area        Alaska        2280
# 50371           Wade Hampton Census Area        Alaska        2270
# 50372         Valdez-Cordova Census Area        Alaska        2261
# 50373              Skagway-Hoonah-Angoon        Alaska        2232
# 50374  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Gender Absolute Male Absolute LL Male Absolute UL  Year  \
# 0             No Data          No Data          No Data  2004
# ...

# %%
# Finalizing Obesity county female dataframe
df_obese_female['Gender'] = 'Female'
df_obese_female.rename(columns={'Female Absolute':'Gender Absolute','Female Percentage':'Gender Percentage'},inplace=True)
df_obese_female
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                      Dallas County         Texas       48113
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Gender Absolute Female Absolute LL Female Absolute UL  Year  \
# 0             No Data            No Data            No Data  2004
# ...

# %%
# Checking for No data in Obesity county female
missing_obese_county_female = df_obese_female[(df_obese_female['Gender Absolute']=='No Data')|(df_obese_female['Gender Percentage']=='No Data')]
missing_obese_county_female
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 50370    Wrangell-Petersburg Census Area        Alaska        2280
# 50371           Wade Hampton Census Area        Alaska        2270
# 50372         Valdez-Cordova Census Area        Alaska        2261
# 50373              Skagway-Hoonah-Angoon        Alaska        2232
# 50374  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Gender Absolute Female Absolute LL Female Absolute UL  Year  \
# 0             No Data            No Data            No Data  2004
# ...

# %%
#Creating Gender Dataframe
obese_county_gender = pd.concat([df_obese_male,df_obese_female],axis=0)
obese_county_gender
# Out:
#                                   County         State  CountyFIPS  \
# 0                   Oglala Lakota County  South Dakota       46102
# 1              Wrangell City and Borough        Alaska        2275
# 2                   Skagway Municipality        Alaska        2230
# 3      Prince of Wales-Hyder Census Area        Alaska        2198
# 4                     Petersburg Borough        Alaska        2195
# ...                                  ...           ...         ...
# 53513                      Dallas County         Texas       48113
# 53514                    Maricopa County       Arizona        4013
# 53515                        Cook County      Illinois       17031
# 53516                      Harris County         Texas       48201
# 53517                 Los Angeles County    California        6037
#
#       Gender Absolute Male Absolute LL Male Absolute UL  Year  \
# 0             No Data          No Data          No Data  2004
# ...

# %%
# Finalizing Obesity county age 20 to 44 dataframe
df_obese_age_20_to_44 = df_obese_age_20_to_44.rename(columns={'Age_20_to_44 Absolute':'Age Obesity Absolute','Age_20_to_44 Percentage':'Age Obesity Percentage' })
df_obese_age_20_to_44['Age'] = '20-44'
df_obese_age_20_to_44
# Out:
#                    County       State  CountyFIPS Age Obesity Absolute  \
# 0           Loving County       Texas       48301           Suppressed
# 1          Kalawao County      Hawaii       15005           Suppressed
# 2           Arthur County    Nebraska       31005                   17
# 3             King County       Texas       48269                   18
# 4           Blaine County    Nebraska       31009                   21
# ...                   ...         ...         ...                  ...
# 53395       Dallas County       Texas       48113               281916
# 53396     Maricopa County     Arizona        4013               410282
# 53397         Cook County    Illinois       17031               445411
# 53398       Harris County       Texas       48201               508507
# 53399  Los Angeles County  California        6037               817871
#
#       Age_20_to_44 Absolute LL Age_20_to_44 Absolute UL  Year  \
# ...

# %%
# Checking for No data in Obesity county age 20 to 44
missing_df_obese_age_20_to_44 = df_obese_age_20_to_44[(df_obese_age_20_to_44['Age Obesity Absolute']=='No Data') | (df_obese_age_20_to_44['Age Obesity Percentage']=='No Data')]
missing_df_obese_age_20_to_44
# Out:
#                                   County         State  CountyFIPS  \
# 50250                       Bedford City      Virginia       51515
# 50251                     Shannon County  South Dakota       46113
# 50252    Wrangell-Petersburg Census Area        Alaska        2280
# 50253           Wade Hampton Census Area        Alaska        2270
# 50254         Valdez-Cordova Census Area        Alaska        2261
# 50255              Skagway-Hoonah-Angoon        Alaska        2232
# 50256  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Age Obesity Absolute Age_20_to_44 Absolute LL Age_20_to_44 Absolute UL  \
# 50250              No Data                  No Data                  No Data
# 50251              No Data                  No Data                  No Data
# 50252              No Data                  No Data                  No Data
# 50253              No Data                  No Data                  No Data
# ...

# %%
# Finalizing Obesity county age 45 to 64 dataframe
df_obese_age_45_to_64 = df_obese_age_45_to_64.rename(columns={'Age_45_to_64 Absolute':'Age Obesity Absolute','Age_45_to_64 Percentage':'Age Obesity Percentage' })
df_obese_age_45_to_64['Age'] = '45-64'
df_obese_age_45_to_64
# Out:
#                    County       State  CountyFIPS Age Obesity Absolute  \
# 0           Loving County       Texas       48301           Suppressed
# 1          Kalawao County      Hawaii       15005                   14
# 2             King County       Texas       48269                   18
# 3           Arthur County    Nebraska       31005                   23
# 4           Kenedy County       Texas       48261                   24
# ...                   ...         ...         ...                  ...
# 53395    San Diego County  California        6073               236123
# 53396     Maricopa County     Arizona        4013               372088
# 53397         Cook County    Illinois       17031               391096
# 53398       Harris County       Texas       48201               441893
# 53399  Los Angeles County  California        6037               787052
#
#       Age_45_to_64 Absolute LL Age_45_to_64 Absolute UL  Year  \
# ...

# %%
# Checking for No data in Obesity county age 45 to 64
missing_df_obese_age_45_to_64 = df_obese_age_45_to_64[(df_obese_age_45_to_64['Age Obesity Absolute']=='No Data') | (df_obese_age_45_to_64['Age Obesity Percentage']=='No Data')]
missing_df_obese_age_45_to_64
# Out:
#                                   County         State  CountyFIPS  \
# 50250                       Bedford City      Virginia       51515
# 50251                     Shannon County  South Dakota       46113
# 50252    Wrangell-Petersburg Census Area        Alaska        2280
# 50253           Wade Hampton Census Area        Alaska        2270
# 50254         Valdez-Cordova Census Area        Alaska        2261
# 50255              Skagway-Hoonah-Angoon        Alaska        2232
# 50256  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Age Obesity Absolute Age_45_to_64 Absolute LL Age_45_to_64 Absolute UL  \
# 50250              No Data                  No Data                  No Data
# 50251              No Data                  No Data                  No Data
# 50252              No Data                  No Data                  No Data
# 50253              No Data                  No Data                  No Data
# ...

# %%
# Finalizing Obesity county age 65 to beyond dataframe
df_obese_age_65_to_beyond = df_obese_age_65_to_beyond.rename(columns={'Age_65_to_beyond Absolute':'Age Obesity Absolute','Age_65_to_beyond Percentage':'Age Obesity Percentage' })
df_obese_age_65_to_beyond['Age'] = '65-beyond'
df_obese_age_65_to_beyond
# Out:
#                          County       State  CountyFIPS Age Obesity Absolute  \
# 0                 Loving County       Texas       48301           Suppressed
# 1                Kalawao County      Hawaii       15005           Suppressed
# 2                   King County       Texas       48269           Suppressed
# 3               San Juan County    Colorado        8111           Suppressed
# 4      Yakutat City and Borough      Alaska        2282           Suppressed
# ...                         ...         ...         ...                  ...
# 53395          San Diego County  California        6073               112177
# 53396             Harris County       Texas       48201               155223
# 53397           Maricopa County     Arizona        4013               184304
# 53398               Cook County    Illinois       17031               208557
# 53399        Los Angeles County  California        6037               350530
#
# ...

# %%
# Checking for No data in Obesity county age 65 to beyond
missing_df_obese_age_65_to_beyond = df_obese_age_65_to_beyond[(df_obese_age_65_to_beyond['Age Obesity Absolute']=='No Data') | (df_obese_age_65_to_beyond['Age Obesity Percentage']=='No Data')]
missing_df_obese_age_65_to_beyond
# Out:
#                                   County         State  CountyFIPS  \
# 15705                     Kalawao County        Hawaii       15005
# 50250                       Bedford City      Virginia       51515
# 50251                     Shannon County  South Dakota       46113
# 50252    Wrangell-Petersburg Census Area        Alaska        2280
# 50253           Wade Hampton Census Area        Alaska        2270
# 50254         Valdez-Cordova Census Area        Alaska        2261
# 50255              Skagway-Hoonah-Angoon        Alaska        2232
# 50256  Prince of Wales - Outer Ketchikan        Alaska        2201
#
#       Age Obesity Absolute Age_65_to_beyond Absolute LL  \
# 15705                    0                            0
# 50250              No Data                      No Data
# 50251              No Data                      No Data
# 50252              No Data                      No Data
# 50253              No Data                      No Data
# ...

# %%
#Creating Age Dataframe
obese_county_age = pd.concat([df_obese_age_20_to_44,df_obese_age_45_to_64,df_obese_age_65_to_beyond],axis=0)
obese_county_age
# Out:
#                    County       State  CountyFIPS Age Obesity Absolute  \
# 0           Loving County       Texas       48301           Suppressed
# 1          Kalawao County      Hawaii       15005           Suppressed
# 2           Arthur County    Nebraska       31005                   17
# 3             King County       Texas       48269                   18
# 4           Blaine County    Nebraska       31009                   21
# ...                   ...         ...         ...                  ...
# 53395    San Diego County  California        6073               112177
# 53396       Harris County       Texas       48201               155223
# 53397     Maricopa County     Arizona        4013               184304
# 53398         Cook County    Illinois       17031               208557
# 53399  Los Angeles County  California        6037               350530
#
#       Age_20_to_44 Absolute LL Age_20_to_44 Absolute UL  Year  \
# ...

# %%
# Finalizing Total County Dataframe and then mergining it with state tax data frame
obese_county_data = df_obese_total.merge(obese_county_gender, on=['State','County','CountyFIPS','Year'], how='inner').merge(obese_county_age, on=['State','County','CountyFIPS','Year'], how='inner').sort_values(by=['State','County','CountyFIPS','Year']).reset_index(drop=True)
obese_county_data = obese_county_data.merge(df_state, how = 'inner', on=['State','Year'])
obese_county_data
# Out:
#                 County    State  CountyFIPS Total Absolute Total Absolute LL  \
# 0       Autauga County  Alabama        1001           7213              5224
# 1       Autauga County  Alabama        1001           7213              5224
# 2       Autauga County  Alabama        1001           7213              5224
# 3       Autauga County  Alabama        1001           7213              5224
# 4       Autauga County  Alabama        1001           7213              5224
# ...                ...      ...         ...            ...               ...
# 640591   Weston County  Wyoming       56045           1659              1340
# 640592   Weston County  Wyoming       56045           1659              1340
# 640593   Weston County  Wyoming       56045           1659              1340
# 640594   Weston County  Wyoming       56045           1659              1340
# 640595   Weston County  Wyoming       56045           1659              1340
#
# ...

# %%
obese_county_data.to_excel('obese_County_Data_New.xlsx',index=False)
